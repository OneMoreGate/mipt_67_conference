# %%
from classes_V3 import *

# %%
d_sep = DC_IV('sep_samples')

# %%
d_sep.get_contacts()
# Out:
# ['14G-150']

# %%
fig, ax = plt.subplots(figsize = (8,5))
d_sep.draw_multiple_lines('14G-150', ax, measurs=[4,6,8,9,10,13,15,17,21,22,24,26,27,29], color = '#c8c8c8')
d_sep.draw_single_line('14G-150', ax, 21, color = 'k', linewidth = 2)
ax.set(yscale='log', xlim=[-3.5, 4.5], ylim=(10 ** (-13), 10 ** (-2)))
ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(0.25))
y_major = ticker.LogLocator(numticks = 20)
y_minor = ticker.LogLocator(subs = np.arange(1.0, 10.0) * 0.1, numticks = 20)
ax.yaxis.set_major_locator(y_major)
ax.yaxis.set_minor_locator(y_minor)
ax.tick_params('both', which = 'both', direction = 'in', labelsize=15)
